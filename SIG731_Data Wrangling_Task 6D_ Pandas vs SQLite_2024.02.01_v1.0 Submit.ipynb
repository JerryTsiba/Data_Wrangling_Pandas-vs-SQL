# %% [markdown]
# # SIG731_Data Wrangling using Pandas vs SQLite:
# # Project Report_Task 6D
#
#   By: Jerry Lawrence TSIBA
#
#   Master in Data Sciences, Deakin University, Jan 2025
#
#   Student ID: s224670832
#
#   Mails: Jerry-Lawrence@live.fr or s224670832@deakin.edu.au

# %% [markdown]
# # **1. Introduction**
#
# Tasks 5–8 are not obligatory; you can submit them in any order (or decide not to tackle them at all).
# C/D/HD is merely a subjective estimate of their difficulty level. For each task that you successfully
# complete, you score 10 points (and for those that are not 100% correct, no points will be given).
# This task is related to Section 4.6 (see the Learning Resources on the unit site; see also Chapter 13 of
# our book). In case of any problems/questions, do hot hesitate to attend our on-campus/online classes.
# The due date for submission is Week 6. After this due day, the evaluation team will not provide any
# feedback for your work in Olympus. The submission due day is 9th February (Sunday). Start tackling
# this task as early as possible. If we find your first solution incomplete or otherwise incorrect, you will
# still be able to amend it based on the generous feedback we will give you (allow 3–5 working days). In
# case of any problems/questions, do hot hesitate to attend our online classes or use the Discussion Board
# on the unit site.

# %% [markdown]
# # **2. Task Overview**
#
# You will study the dataset called nycflights13. It gives information about all 336,776 flights that
# departed in 2013 from the three New York (in the US) airports (EWR, JFK, and LGA) to destinations
# in the United
#
# This document was originally developed by Dr. Marek Gagolewski. It was subsequently revised by Dr.
# Yang Li (Kelvin) during the work at the School of Information Technology, Deakin University, for the
# unit SIT220/731 Data Wrangling, Trimester 1, 2024.©
# States, Puerto Rico, and the American Virgin Islands.
#
# Download the following data files from our unit site (Learning Resources → Data):
#
# • nycflights13_flights.csv.gz – flights information,
#
# • nycflights13_airlines.csv.gz – decodes two letter carrier codes,
#
# • nycflights13_airports.csv.gz – airport data,
#
# • nycflights13_planes.csv.gz – plane data,
#
# • nycflights13_weather.csv.gz – hourly meteorological data for LGA, JFK, and EWR.
#
# Refer to the comment lines in the CSV files (note that they are gzipped) for more details about each
# column.
#
# Just like in the 6th part of Module 4 (4.6. Database Access), you aim is to use pandas to come up
# with results equivalent to those that correspond to example SQL queries.2
#
# Important. This time, you will generate the Jupyter/IPython notebook using jupytext. Write all your
# codeinasingle.pyfile(Pythonsourcescript;aplaintextfile)inthepy:percentformat,anddefineMarkdown chunks therein using a special syntax (see the jupytext documentation for more details). Pair this source file with a notebook in the .ipynb format (how to do that you will have to learn yourself – this is part of
# this D-level task).

# %% [markdown]
# # Import of libraries

# %%
import pandas as pd
import gzip
import csv
import io
import sqlite3
import pandas as pd

# %% [markdown]
# **Load dataset**

# %%
# Access and read the dataset
url_airlines = 'C:/Users/JTsiba/data_files/airlines.csv'
url_airports = 'C:/Users/JTsiba/data_files/airports.csv'
url_flights = 'C:/Users/JTsiba/data_files/flights.csv'
url_planes = 'C:/Users/JTsiba/data_files/planes.csv'
url_weather = 'C:/Users/JTsiba/data_files/weather.csv'

# Now, let's use pd.read_csv:
airlines = pd.read_csv(url_airlines)
airports = pd.read_csv(url_airports)
flights = pd.read_csv(url_flights)
planes = pd.read_csv(url_planes)
weather = pd.read_csv(url_weather)

# %%
airlines.head()
# Out:
#   carrier                    name
# 0      9E       Endeavor Air Inc.
# 1      AA  American Airlines Inc.
# 2      AS    Alaska Airlines Inc.
# 3      B6         JetBlue Airways
# 4      DL    Delta Air Lines Inc.

# %%
airports.head()
# Out:
#    faa                           name        lat        lon   alt  tz dst  \
# 0  04G              Lansdowne Airport  41.130472 -80.619583  1044  -5   A
# 1  06A  Moton Field Municipal Airport  32.460572 -85.680028   264  -6   A
# 2  06C            Schaumburg Regional  41.989341 -88.101243   801  -6   A
# 3  06N                Randall Airport  41.431912 -74.391561   523  -5   A
# 4  09J          Jekyll Island Airport  31.074472 -81.427778    11  -5   A
#
#               tzone
# 0  America/New_York
# 1   America/Chicago
# 2   America/Chicago
# 3  America/New_York
# 4  America/New_York

# %%
flights.head()
# Out:
#    year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0  2013      1    1     517.0             515        2.0     830.0
# 1  2013      1    1     533.0             529        4.0     850.0
# 2  2013      1    1     542.0             540        2.0     923.0
# 3  2013      1    1     544.0             545       -1.0    1004.0
# 4  2013      1    1     554.0             600       -6.0     812.0
#
#    sched_arr_time  arr_delay carrier  flight tailnum origin dest  air_time  \
# 0             819       11.0      UA    1545  N14228    EWR  IAH     227.0
# 1             830       20.0      UA    1714  N24211    LGA  IAH     227.0
# 2             850       33.0      AA    1141  N619AA    JFK  MIA     160.0
# 3            1022      -18.0      B6     725  N804JB    JFK  BQN     183.0
# 4             837      -25.0      DL     461  N668DN    LGA  ATL     116.0
#
#    distance  hour  minute      time_hour
# 0      1400     5      15  1/1/2013 5:00
# ...

# %%
planes.head()
# Out:
#   tailnum    year                     type      manufacturer      model  \
# 0  N10156  2004.0  Fixed wing multi engine           EMBRAER  EMB-145XR
# 1  N102UW  1998.0  Fixed wing multi engine  AIRBUS INDUSTRIE   A320-214
# 2  N103US  1999.0  Fixed wing multi engine  AIRBUS INDUSTRIE   A320-214
# 3  N104UW  1999.0  Fixed wing multi engine  AIRBUS INDUSTRIE   A320-214
# 4  N10575  2002.0  Fixed wing multi engine           EMBRAER  EMB-145LR
#
#    engines  seats  speed     engine
# 0        2     55    NaN  Turbo-fan
# 1        2    182    NaN  Turbo-fan
# 2        2    182    NaN  Turbo-fan
# 3        2    182    NaN  Turbo-fan
# 4        2     55    NaN  Turbo-fan

# %%
weather.head()
# Out:
#   origin  year  month  day  hour   temp   dewp  humid  wind_dir  wind_speed  \
# 0    EWR  2013      1    1     0  37.04  21.92  53.97     230.0    10.35702
# 1    EWR  2013      1    1     1  37.04  21.92  53.97     230.0    13.80936
# 2    EWR  2013      1    1     2  37.94  21.92  52.09     230.0    12.65858
# 3    EWR  2013      1    1     3  37.94  23.00  54.51     230.0    13.80936
# 4    EWR  2013      1    1     4  37.94  24.08  57.04     240.0    14.96014
#
#    wind_gust  precip  pressure  visib      time_hour
# 0  11.918651     0.0    1013.9   10.0  1/1/2013 1:00
# 1  15.891535     0.0    1013.0   10.0  1/1/2013 2:00
# 2  14.567241     0.0    1012.6   10.0  1/1/2013 3:00
# 3  15.891535     0.0    1012.7   10.0  1/1/2013 4:00
# 4  17.215830     0.0    1012.8   10.0  1/1/2013 5:00

# %% [markdown]
# **1. Establish a connection with a new SQLite database on your disk**

# %%
# Path to save the SQLite database
db_path = "/content/base_data.db"

# Establishing the connection
conn = sqlite3.connect(db_path)
print("Connected to SQLite database!")

# Reading the CSV files into Pandas DataFrames
url_airlines = 'C:/Users/JTsiba/data_files/airlines.csv'
url_airports = 'C:/Users/JTsiba/data_files/airports.csv'
url_flights = 'C:/Users/JTsiba/data_files/flights.csv'
url_planes = 'C:/Users/JTsiba/data_files/planes.csv'
url_weather = 'C:/Users/JTsiba/data_files/weather.csv'

airlines = pd.read_csv(url_airlines)
airports = pd.read_csv(url_airports)
flights = pd.read_csv(url_flights)
planes = pd.read_csv(url_planes)
weather = pd.read_csv(url_weather)

# Loading the DataFrames into SQLite tables
airlines.to_sql('airlines', conn, if_exists='replace', index=False)
airports.to_sql('airports', conn, if_exists='replace', index=False)
flights.to_sql('flights', conn, if_exists='replace', index=False)
planes.to_sql('planes', conn, if_exists='replace', index=False)
weather.to_sql('weather', conn, if_exists='replace', index=False)

print("All files have been loaded into the SQLite database!")

# Close the connection when done
#conn.close()
# Out:
# Connected to SQLite database!
# All files have been loaded into the SQLite database!

# %% [markdown]
# **2. Export all the CSV files to the said database**

# %%
# Path to SQLite database
db_path = "/content/base_data.db"

# Establish connection to SQLite database
conn = sqlite3.connect(db_path)
print("Connected to SQLite database!")

# Define CSV file paths
csv_files = {
url_airlines = 'C:/Users/JTsiba/data_files/airlines.csv'
url_airports = 'C:/Users/JTsiba/data_files/airports.csv'
url_flights = 'C:/Users/JTsiba/data_files/flights.csv'
url_planes = 'C:/Users/JTsiba/data_files/planes.csv'
url_weather = 'C:/Users/JTsiba/data_files/weather.csv'
}

# Loop through each CSV file and export to SQLite database
for table_name, file_path in csv_files.items():
    df = pd.read_csv(file_path)  # Read CSV into a Pandas DataFrame
    df.to_sql(table_name, conn, if_exists='replace', index=False)  # Export to SQLite
    print(f"Exported {table_name}.csv to {table_name} table in SQLite!")

# Close the database connection
#conn.close()
print("All CSV files have been successfully exported to the SQLite database!")
# Out:
# Connected to SQLite database!
# Exported airlines.csv to airlines table in SQLite!
# Exported airports.csv to airports table in SQLite!
# Exported flights.csv to flights table in SQLite!
# Exported planes.csv to planes table in SQLite!
# Exported weather.csv to weather table in SQLite!
# All CSV files have been successfully exported to the SQLite database!

# %%
#To check if the tables were successfully created, let's run:
conn = sqlite3.connect(db_path)  # Reconnect to the database
cursor = conn.cursor()

# List all tables
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
tables = cursor.fetchall()
print("Tables in the database:", tables)

#conn.close()
# Out:
# Tables in the database: [('airlines',), ('airports',), ('flights',), ('planes',), ('weather',)]

# %% [markdown]
# **3. For each of the SQL queries below (each query in a separate section), write the code that yields
# equivalent results using pandas only and explain – in your own words – what it does.**

# %% [markdown]
# **3. 1 SELECT DISTINCT engine FROM planes**

# %% [markdown]
# - SQL Query Approach

# %%
task1_sql = pd.read_sql_query("""
    SELECT DISTINCT engine FROM planes
""", conn)

# %%
task1_sql.head()
# Out:
#           engine
# 0        4 Cycle
# 1  Reciprocating
# 2      Turbo-fan
# 3      Turbo-jet
# 4     Turbo-prop

# %% [markdown]
# - Pandas Equivalent Code (Without SQL)

# %%
task1_my = planes[['engine']].drop_duplicates()

# %%
task1_my.head()
# Out:
#           engine
# 0        4 Cycle
# 1  Reciprocating
# 2      Turbo-fan
# 3      Turbo-jet
# 4     Turbo-prop

# %% [markdown]
# - Handling Row Order Differences

# %%
task1_sql = task1_sql.sort_values(by=["engine"]).reset_index(drop=True)
task1_my = task1_my.sort_values(by=["engine"]).reset_index(drop=True)

# Verify both DataFrames are identical
pd.testing.assert_frame_equal(task1_sql, task1_my)

# %%
print(pd.testing.assert_frame_equal(task1_sql, task1_my))
# Out:
# None

# %% [markdown]
# - Observations:
# - - planes[['engine']] → Selects only the engine column from the planes DataFrame.
# - - .drop_duplicates() → Removes duplicate values, keeping only distinct ones (just like DISTINCT in SQL).

# %% [markdown]
# **3. 2 SELECT DISTINCT type, engine FROM planes**

# %% [markdown]
# - SQL Query Approach

# %%
task2_sql = pd.read_sql_query("""
    SELECT DISTINCT type, engine FROM planes
""", conn)

# %%
task2_sql.head()
# Out:
#                        type         engine
# 0   Fixed wing multi engine  Reciprocating
# 1   Fixed wing multi engine      Turbo-fan
# 2   Fixed wing multi engine      Turbo-jet
# 3   Fixed wing multi engine     Turbo-prop
# 4  Fixed wing single engine        4 Cycle

# %% [markdown]
# - Pandas Equivalent Code (Without SQL)

# %%
task2_my = planes[['type', 'engine']].drop_duplicates()

# %%
task2_my.head()
# Out:
#                        type         engine
# 0   Fixed wing multi engine  Reciprocating
# 1   Fixed wing multi engine      Turbo-fan
# 2   Fixed wing multi engine      Turbo-jet
# 3   Fixed wing multi engine     Turbo-prop
# 4  Fixed wing single engine        4 Cycle

# %% [markdown]
# - Handling Row Order Differences

# %%
task2_sql = task2_sql.sort_values(by=["type", "engine"]).reset_index(drop=True)
task2_my = task2_my.sort_values(by=["type", "engine"]).reset_index(drop=True)

# Verify both DataFrames are identical
pd.testing.assert_frame_equal(task2_sql, task2_my)

# %%
print(pd.testing.assert_frame_equal(task2_sql, task2_my))
# Out:
# None

# %% [markdown]
# - Observations:
#
# - - planes[['type', 'engine']] → Selects only the type and engine columns from the planes DataFrame.
# - - .drop_duplicates() → Removes duplicate rows, keeping only unique combinations of type and engine

# %% [markdown]
# **3. 3 SELECT COUNT(*), engine FROM planes GROUP BY engine**

# %% [markdown]
# - SQL Query Approach

# %%
task3_sql = pd.read_sql_query("""
    SELECT COUNT(*) AS count, engine
    FROM planes
    GROUP BY engine
""", conn)

# %%
task3_sql.head()
# Out:
#    count         engine
# 0      2        4 Cycle
# 1     28  Reciprocating
# 2   2750      Turbo-fan
# 3    535      Turbo-jet
# 4      2     Turbo-prop

# %% [markdown]
# - Pandas Equivalent Code (Without SQL)

# %%
task3_my = planes.groupby("engine").size().reset_index(name="count")

# %%
task3_my.head()
# Out:
#    count         engine
# 0      2        4 Cycle
# 1     28  Reciprocating
# 2   2750      Turbo-fan
# 3    535      Turbo-jet
# 4      2     Turbo-prop

# %% [markdown]
# - Handling Row Order Differences

# %%
# Reorder the columns in task3_my to match task3_sql
task3_my = task3_my[['count', 'engine']]

# Now, the assertion should pass
pd.testing.assert_frame_equal(task3_sql, task3_my)

# %%
print(pd.testing.assert_frame_equal(task3_sql, task3_my))
# Out:
# None

# %% [markdown]
# - Observations:
#
# - - planes.groupby("engine") → Groups the planes DataFrame by engine.
# - - .size() → Counts the number of rows in each group.
# - - .reset_index(name="count") → Converts the grouped result into a DataFrame with column name count.

# %% [markdown]
# **3. 4 SELECT COUNT(*), engine, type FROM planes GROUP BY engine, type**

# %% [markdown]
# - SQL Query Approach

# %%
task4_sql = pd.read_sql_query("""
    SELECT COUNT(*) AS count, engine, type
    FROM planes
    GROUP BY engine, type
""", conn)

# %%
task4_sql.head()
# Out:
#    count         engine                      type
# 0      2        4 Cycle  Fixed wing single engine
# 1      5  Reciprocating   Fixed wing multi engine
# 2     23  Reciprocating  Fixed wing single engine
# 3   2750      Turbo-fan   Fixed wing multi engine
# 4    535      Turbo-jet   Fixed wing multi engine

# %% [markdown]
# - Pandas Equivalent Code (Without SQL)

# %%
task4_my = planes.groupby(["engine", "type"]).size().reset_index(name="count")

# %%
task4_my.head()
# Out:
#    count         engine                      type
# 0      2        4 Cycle  Fixed wing single engine
# 1      5  Reciprocating   Fixed wing multi engine
# 2     23  Reciprocating  Fixed wing single engine
# 3   2750      Turbo-fan   Fixed wing multi engine
# 4    535      Turbo-jet   Fixed wing multi engine

# %% [markdown]
# - Handling Row Order Differences

# %%
task4_sql = pd.read_sql_query("""
    SELECT COUNT(*) AS count, engine, type
    FROM planes
    GROUP BY engine, type
""", conn)
task4_my = planes.groupby(["engine", "type"]).size().reset_index(name="count")
task4_sql = task4_sql.sort_values(by=["engine", "type"]).reset_index(drop=True)
task4_my = task4_my.sort_values(by=["engine", "type"]).reset_index(drop=True)

# Reorder columns in task4_my to match task4_sql
task4_my = task4_my[['count', 'engine', 'type']]

# Verify both DataFrames are identical
pd.testing.assert_frame_equal(task4_sql, task4_my)

# %%
print(pd.testing.assert_frame_equal(task4_sql, task4_my))
# Out:
# None

# %% [markdown]
# - Observations:

# %% [markdown]
# - - planes.groupby(["engine", "type"]) → Groups the dataset by engine and type.
# - - .size() → Counts the number of occurrences for each (engine, type) group.
# - - .reset_index(name="count") → Converts the result into a DataFrame and renames the count column to "count".

# %% [markdown]
# **3. 5 SELECT MIN(year), AVG(year), MAX(year), engine, manufacturer
# FROM planes
# GROUP BY engine, manufacturer**

# %% [markdown]
# - SQL Query Approach

# %%
task5_sql = pd.read_sql_query("""
    SELECT MIN(year) AS min_year, AVG(year) AS avg_year, MAX(year) AS max_year, engine, manufacturer
    FROM planes
    GROUP BY engine, manufacturer
""", conn)

# %%
task5_sql.head()
# Out:
#    min_year  avg_year  max_year         engine           manufacturer
# 0    1975.0    1975.0    1975.0        4 Cycle                 CESSNA
# 1       NaN       NaN       NaN        4 Cycle            JOHN G HESS
# 2       NaN       NaN       NaN  Reciprocating  AMERICAN AIRCRAFT INC
# 3    2007.0    2007.0    2007.0  Reciprocating     AVIAT AIRCRAFT INC
# 4       NaN       NaN       NaN  Reciprocating          BARKER JACK L

# %% [markdown]
# - Pandas Equivalent Code (Without SQL)

# %%
task5_my = planes.groupby(["engine", "manufacturer"])["year"].agg(["min", "mean", "max"]).reset_index()
task5_my = task5_my.rename(columns={"min": "min_year", "mean": "avg_year", "max": "max_year"})

# %%
task5_my.head()
# Out:
#    min_year  avg_year  max_year         engine           manufacturer
# 0    1975.0    1975.0    1975.0        4 Cycle                 CESSNA
# 1       NaN       NaN       NaN        4 Cycle            JOHN G HESS
# 2       NaN       NaN       NaN  Reciprocating  AMERICAN AIRCRAFT INC
# 3    2007.0    2007.0    2007.0  Reciprocating     AVIAT AIRCRAFT INC
# 4       NaN       NaN       NaN  Reciprocating          BARKER JACK L

# %% [markdown]
# - Handling Row Order Differences

# %%
# Reorder columns in task5_my to match task5_sql
task5_my = task5_my[['min_year', 'avg_year', 'max_year', 'engine', 'manufacturer']]

# Verify both DataFrames are identical
pd.testing.assert_frame_equal(task5_sql, task5_my)

# %%
print(pd.testing.assert_frame_equal(task5_sql, task5_my))
# Out:
# None

# %% [markdown]
# - Observations:
#
# - - planes.groupby(["engine", "manufacturer"]) → Groups the dataset by both engine and manufacturer.
# - - ["year"].agg(["min", "mean", "max"]) → Calculates the minimum (min), average (mean), and maximum (max) of the year column for each group.
# - - .reset_index() → Converts the result back to a DataFrame with default index.
# - - .rename() → Renames the aggregated columns to match the SQL output (min_year, avg_year, and max_year).

# %% [markdown]
# **3. 6 SELECT * FROM planes WHERE speed IS NOT NULL**

# %% [markdown]
# - SQL Query Approach

# %%
task6_sql = pd.read_sql_query("""
    SELECT * FROM planes WHERE speed IS NOT NULL
""", conn)

# %%
task6_sql.head()
# Out:
#   tailnum    year                      type manufacturer       model  engines  \
# 0  N621AA  1975.0  Fixed wing single engine       CESSNA        172M        1
# 1  N201AA  1959.0  Fixed wing single engine       CESSNA         150        1
# 2  N737MQ  1977.0  Fixed wing single engine       CESSNA        172N        1
# 3  N545AA  1976.0  Fixed wing single engine        PIPER  PA-32R-300        1
# 4  N525AA  1980.0   Fixed wing multi engine        PIPER   PA-31-350        2
#
#    seats  speed         engine
# 0      4  108.0        4 Cycle
# 1      2   90.0  Reciprocating
# 2      4  105.0  Reciprocating
# 3      7  126.0  Reciprocating
# 4      8  162.0  Reciprocating

# %% [markdown]
# - Pandas Equivalent Code (Without SQL)

# %%
task6_my = planes[planes['speed'].notnull()]

# %%
task6_my.head()
# Out:
#   tailnum    year                      type manufacturer       model  engines  \
# 0  N621AA  1975.0  Fixed wing single engine       CESSNA        172M        1
# 1  N201AA  1959.0  Fixed wing single engine       CESSNA         150        1
# 2  N737MQ  1977.0  Fixed wing single engine       CESSNA        172N        1
# 3  N545AA  1976.0  Fixed wing single engine        PIPER  PA-32R-300        1
# 4  N525AA  1980.0   Fixed wing multi engine        PIPER   PA-31-350        2
#
#    seats  speed         engine
# 0      4  108.0        4 Cycle
# 1      2   90.0  Reciprocating
# 2      4  105.0  Reciprocating
# 3      7  126.0  Reciprocating
# 4      8  162.0  Reciprocating

# %% [markdown]
# - Handling Row Order Differences

# %%
task6_sql = task6_sql.sort_values(by=["engine"]).reset_index(drop=True)
task6_my = task6_my.sort_values(by=["engine"]).reset_index(drop=True)

# Verify both DataFrames are identical
pd.testing.assert_frame_equal(task6_sql, task6_my)

# %%
print(pd.testing.assert_frame_equal(task6_sql, task6_my))
# Out:
# None

# %% [markdown]
# - Observations:
#
# - - planes['speed'].notnull() → This creates a boolean mask where each value in the speed column is checked if it is not null (True if not null, False if null).
# - - planes[...] → Filters the planes DataFrame by selecting only the rows where the condition is True, i.e., the rows with non-null speed values.

# %% [markdown]
# **3. 7 SELECT tailnum FROM planes
# WHERE seats BETWEEN 150 AND 210 AND year >= 2011**

# %% [markdown]
# - SQL Query Approach

# %%
task7_sql = pd.read_sql_query("""
    SELECT tailnum FROM planes
    WHERE seats BETWEEN 150 AND 210 AND year >= 2011
""", conn)

# %%
task7_sql.head()
# Out:
#   tailnum
# 0  N150UW
# 1  N151UW
# 2  N152UW
# 3  N153UW
# 4  N154UW

# %% [markdown]
# - Pandas Equivalent Code (Without SQL)

# %%
task7_my = planes[(planes['seats'] >= 150) & (planes['seats'] <= 210) & (planes['year'] >= 2011)][['tailnum']]

# %%
task7_my.head()
# Out:
#   tailnum
# 0  N150UW
# 1  N151UW
# 2  N152UW
# 3  N153UW
# 4  N154UW

# %% [markdown]
# - Handling Row Order Differences

# %%
task7_sql = task7_sql.sort_values(by=["tailnum"]).reset_index(drop=True)
task7_my = task7_my.sort_values(by=["tailnum"]).reset_index(drop=True)

# Verify both DataFrames are identical
pd.testing.assert_frame_equal(task7_sql, task7_my)

# %%
print(pd.testing.assert_frame_equal(task7_sql, task7_my))
# Out:
# None

# %% [markdown]
# - Observations:
#
# - - (planes['seats'] >= 150) & (planes['seats'] <= 210) → Filters rows where the seats value is between 150 and 210.
# - - (planes['year'] >= 2011) → Filters rows where the year is greater than or equal to 2011.
# - - & → This is the AND operator, which ensures both conditions for seats and year are met simultaneously.
# - - [['tailnum']] → Selects only the tailnum column to match the SQL query's output.

# %% [markdown]
# **3. 8 SELECT tailnum, manufacturer, seats FROM planes
# WHERE manufacturer IN ("BOEING", "AIRBUS", "EMBRAER") AND seats>390**

# %% [markdown]
# - SQL Query Approach

# %%
task8_sql = pd.read_sql_query("""
    SELECT tailnum, manufacturer, seats
    FROM planes
    WHERE manufacturer IN ("BOEING", "AIRBUS", "EMBRAER") AND seats > 390
""", conn)

# %%
task8_sql.head()
# Out:
#   tailnum manufacturer  seats
# 0  N206UA       BOEING    400
# 1  N228UA       BOEING    400
# 2  N272AT       BOEING    400
# 3  N57016       BOEING    400
# 4  N670US       BOEING    450

# %% [markdown]
# - Pandas Equivalent Code (Without SQL)

# %%
task8_my = planes[(planes['manufacturer'].isin(['BOEING', 'AIRBUS', 'EMBRAER'])) & (planes['seats'] > 390)][['tailnum', 'manufacturer', 'seats']]

# %%
task8_my.head()
# Out:
#   tailnum manufacturer  seats
# 0  N206UA       BOEING    400
# 1  N228UA       BOEING    400
# 2  N272AT       BOEING    400
# 3  N57016       BOEING    400
# 4  N670US       BOEING    450

# %% [markdown]
# - Handling Row Order Differences

# %%
task8_sql = task8_sql.sort_values(by=["tailnum"]).reset_index(drop=True)
task8_my = task8_my.sort_values(by=["tailnum"]).reset_index(drop=True)

# Verify both DataFrames are identical
pd.testing.assert_frame_equal(task8_sql, task8_my)

# %%
print(pd.testing.assert_frame_equal(task8_sql, task8_my))
# Out:
# None

# %% [markdown]
# - Observations:
#
# - - planes['manufacturer'].isin(['BOEING', 'AIRBUS', 'EMBRAER']) → Filters rows where the manufacturer is either "BOEING", "AIRBUS", or "EMBRAER". The .isin() method is used to check if the manufacturer value is one of the listed options.
# - - planes['seats'] > 390 → Filters rows where the seats value is greater than 390.
# - - & → This is the AND operator, ensuring both conditions are met simultaneously.
# - - [['tailnum', 'manufacturer', 'seats']] → Selects only the specified columns (tailnum, manufacturer, and seats) for the result.

# %% [markdown]
# **3. 9 SELECT DISTINCT year, seats FROM planes
# WHERE year >= 2012 ORDER BY year ASC, seats DESC**

# %% [markdown]
# - SQL Query Approach

# %%
task9_sql = pd.read_sql_query("""
    SELECT DISTINCT year, seats
    FROM planes
    WHERE year >= 2012
    ORDER BY year ASC, seats DESC
""", conn)

# %%
task9_sql.head()
# Out:
#      year  seats
# 0  2012.0    379
# 1  2012.0    377
# 2  2012.0    260
# 3  2012.0    222
# 4  2012.0    200

# %% [markdown]
# - Pandas Equivalent Code (Without SQL)

# %%
task9_my = planes[planes['year'] >= 2012][['year', 'seats']].drop_duplicates().sort_values(by=['year', 'seats'], ascending=[True, False])

# %%
task9_my.head()
# Out:
#      year  seats
# 0  2012.0    379
# 1  2012.0    377
# 2  2012.0    260
# 3  2012.0    222
# 4  2012.0    200

# %% [markdown]
# - Handling Row Order Differences

# %%
task9_sql = task9_sql.sort_values(by=["year", "seats"], ascending=[True, False]).reset_index(drop=True)
task9_my = task9_my.sort_values(by=["year", "seats"], ascending=[True, False]).reset_index(drop=True)

# Verify both DataFrames are identical
pd.testing.assert_frame_equal(task9_sql, task9_my)

# %%
print(pd.testing.assert_frame_equal(task9_sql, task9_my))
# Out:
# None

# %% [markdown]
# - Observations:
#
# - - planes['year'] >= 2012 → Filters rows where the year is greater than or equal to 2012.
# - - [['year', 'seats']] → Selects only the year and seats columns from the DataFrame.
# - - .drop_duplicates() → Removes any duplicate rows, keeping only distinct combinations of year and seats.
# - - .sort_values(by=['year', 'seats'], ascending=[True, False]) → Sorts the result by:
# - - - year in ascending order (True).
# - - - seats in descending order (False).

# %% [markdown]
# **3. 10 SELECT DISTINCT year, seats FROM planes
# WHERE year >= 2012 ORDER BY seats DESC, year ASC**

# %% [markdown]
# - SQL Query Approach

# %%
task10_sql = pd.read_sql_query("""
    SELECT DISTINCT year, seats
    FROM planes
    WHERE year >= 2012
    ORDER BY seats DESC, year ASC
""", conn)

# %%
task10_sql.head()
# Out:
#      year  seats
# 0  2012.0    379
# 1  2013.0    379
# 2  2012.0    377
# 3  2013.0    377
# 4  2012.0    260

# %% [markdown]
# - Pandas Equivalent Code (Without SQL)

# %%
task10_my = planes[planes['year'] >= 2012][['year', 'seats']].drop_duplicates().sort_values(by=['seats', 'year'], ascending=[False, True])

# %%
task10_my.head()
# Out:
#      year  seats
# 0  2012.0    379
# 1  2013.0    379
# 2  2012.0    377
# 3  2013.0    377
# 4  2012.0    260

# %% [markdown]
# - Handling Row Order Differences

# %%
task10_sql = task10_sql.sort_values(by=["seats", "year"], ascending=[False, True]).reset_index(drop=True)
task10_my = task10_my.sort_values(by=["seats", "year"], ascending=[False, True]).reset_index(drop=True)

# Verify both DataFrames are identical
pd.testing.assert_frame_equal(task10_sql, task10_my)

# %%
print(pd.testing.assert_frame_equal(task10_sql, task10_my))
# Out:
# None

# %% [markdown]
# - Observations:
#
# - - planes['year'] >= 2012 → Filters the rows where the year is greater than or equal to 2012.
# - - [['year', 'seats']] → Selects only the year and seats columns from the DataFrame.
# - - .drop_duplicates() → Removes duplicate rows based on the selected columns (year and seats), leaving only distinct pairs.
# - - .sort_values(by=['seats', 'year'], ascending=[False, True]) → Sorts the result by:
# - - - seats in descending order (False).
# - - - year in ascending order (True).

# %% [markdown]
# **3. 11 SELECT manufacturer, COUNT(*) FROM planes
# WHERE seats > 200 GROUP BY manufacturer**

# %% [markdown]
# - SQL Query Approach

# %%
task11_sql = pd.read_sql_query("""
    SELECT manufacturer, COUNT(*)
    FROM planes
    WHERE seats > 200
    GROUP BY manufacturer
""", conn)

# %%
task11_sql.head( )
# Out:
#        manufacturer  count
# 0            AIRBUS     66
# 1  AIRBUS INDUSTRIE      4
# 2            BOEING    225

# %% [markdown]
# - Pandas Equivalent Code (Without SQL)

# %%
task11_my = planes[planes['seats'] > 200].groupby('manufacturer').size().reset_index(name='count')

# %%
task11_my.head()
# Out:
#        manufacturer  count
# 0            AIRBUS     66
# 1  AIRBUS INDUSTRIE      4
# 2            BOEING    225

# %% [markdown]
# - Handling Row Order Differences

# %%
# Rename the 'COUNT(*)' column in task11_sql to 'count' to match task11_my
task11_sql = task11_sql.rename(columns={'COUNT(*)': 'count'})

# Now, the assertion should pass
pd.testing.assert_frame_equal(task11_sql, task11_my)

# %%
print(pd.testing.assert_frame_equal(task11_sql, task11_my))
# Out:
# None

# %% [markdown]
# - Observations:
#
# - - planes['seats'] > 200 → Filters the rows where the number of seats is greater than 200.
# - - .groupby('manufacturer') → Groups the DataFrame by the manufacturer column.
# - - .size() → Counts the number of rows in each group (i.e., the number of planes for each manufacturer with more than 200 seats).
# - - .reset_index(name='count') → Resets the index and renames the resulting column from size to count.

# %% [markdown]
# **3. 12 SELECT manufacturer, COUNT(*) FROM planes
# GROUP BY manufacturer HAVING COUNT(*) > 10**

# %% [markdown]
# - SQL Query Approach

# %%
task12_sql = pd.read_sql_query("""
    SELECT manufacturer, COUNT(*)
    FROM planes
    GROUP BY manufacturer
    HAVING COUNT(*) > 10
""", conn)

# %%
task12_sql.head()
# Out:
#        manufacturer  count
# 0            AIRBUS    336
# 1  AIRBUS INDUSTRIE    400
# 2            BOEING   1630
# 3    BOMBARDIER INC    368
# 4           EMBRAER    299

# %% [markdown]
# - Pandas Equivalent Code (Without SQL)

# %%
task12_my = planes.groupby('manufacturer').size().reset_index(name='count')
task12_my = task12_my[task12_my['count'] > 10]

# %%
task12_my.head()
# Out:
#        manufacturer  count
# 0            AIRBUS    336
# 1  AIRBUS INDUSTRIE    400
# 2            BOEING   1630
# 3    BOMBARDIER INC    368
# 4           EMBRAER    299

# %% [markdown]
# - Handling Row Order Differences

# %%
task12_sql = task12_sql.rename(columns={'COUNT(*)': 'count'})  # Rename 'COUNT(*)' to 'count'
task12_sql = task12_sql.sort_values(by=["manufacturer"]).reset_index(drop=True)
task12_my = task12_my.sort_values(by=["manufacturer"]).reset_index(drop=True)

# Verify both DataFrames are identical
pd.testing.assert_frame_equal(task12_sql, task12_my)

# %%
print(pd.testing.assert_frame_equal(task12_sql, task12_my) )
# Out:
# None

# %% [markdown]
# - Observations:
#
# - - planes.groupby('manufacturer') → Groups the DataFrame by the manufacturer column.
# - - .size() → Counts the number of rows in each group (i.e., the number of planes for each manufacturer).
# - - .reset_index(name='count') → Resets the index and renames the resulting column from size to count.
# - - task12_my[task12_my['count'] > 10] → Filters the grouped DataFrame to keep only the rows where the count is greater than 10.

# %% [markdown]
# **3. 13 SELECT manufacturer, COUNT(*) FROM planes
# WHERE seats > 200 GROUP BY manufacturer HAVING COUNT(*) > 10**

# %% [markdown]
# - SQL Query Approach

# %%
task13_sql = pd.read_sql_query("""
    SELECT manufacturer, COUNT(*)
    FROM planes
    WHERE seats > 200
    GROUP BY manufacturer
    HAVING COUNT(*) > 10
""", conn)

# %%
task13_sql.head()
# Out:
#   manufacturer  count
# 0       AIRBUS     66
# 1       BOEING    225

# %% [markdown]
# - Pandas Equivalent Code (Without SQL)

# %%
task13_my = planes[planes['seats'] > 200].groupby('manufacturer').size().reset_index(name='count')
task13_my = task13_my[task13_my['count'] > 10]

# %%
task13_my.head()
# Out:
#   manufacturer  count
# 0       AIRBUS     66
# 1       BOEING    225

# %% [markdown]
# - Handling Row Order Differences

# %%
# Rename the 'COUNT(*)' column in task13_sql to 'count' to match task13_my
task13_sql = task13_sql.rename(columns={'COUNT(*)': 'count'})

task13_sql = task13_sql.sort_values(by=["manufacturer"]).reset_index(drop=True)
task13_my = task13_my.sort_values(by=["manufacturer"]).reset_index(drop=True)

# Verify both DataFrames are identical
pd.testing.assert_frame_equal(task13_sql, task13_my)

# %%
print(pd.testing.assert_frame_equal(task13_sql, task13_my))
# Out:
# None

# %% [markdown]
# - Observations:
#
# - - planes[planes['seats'] > 200] → Filters the DataFrame to keep only rows where the seats column is greater than 200.
# - - .groupby('manufacturer') → Groups the filtered DataFrame by the manufacturer column.
# - - .size() → Counts the number of rows in each group, i.e., the number of planes for each manufacturer with more than 200 seats.
# - - .reset_index(name='count') → Resets the index and renames the resulting column from size to count.
# - - task13_my[task13_my['count'] > 10] → Filters the grouped DataFrame to keep only the rows where the count of planes for a manufacturer is greater than 10.

# %% [markdown]
# **3. 14 SELECT manufacturer, COUNT(*) AS howmany
# FROM planes
# GROUP BY manufacturer
# ORDER BY howmany DESC LIMIT 10**

# %% [markdown]
# - SQL Query Approach

# %%
task14_sql = pd.read_sql_query("""
    SELECT manufacturer, COUNT(*) AS howmany
    FROM planes
    GROUP BY manufacturer
    ORDER BY howmany DESC
    LIMIT 10
""", conn)

# %%
task14_sql.head()
# Out:
#        manufacturer  howmany
# 0            AIRBUS      336
# 1  AIRBUS INDUSTRIE      400
# 2            BOEING     1630
# 3    BOMBARDIER INC      368
# 4          CANADAIR        9

# %% [markdown]
# - Pandas Equivalent Code (Without SQL)

# %%
task14_my = planes.groupby('manufacturer').size().reset_index(name='howmany')
task14_my = task14_my.sort_values(by='howmany', ascending=False).head(10)

# %%
task14_my.head()
# Out:
#        manufacturer  howmany
# 0            AIRBUS      336
# 1  AIRBUS INDUSTRIE      400
# 2            BOEING     1630
# 3    BOMBARDIER INC      368
# 4          CANADAIR        9

# %% [markdown]
# - Handling Row Order Differences

# %%
task14_sql = task14_sql.sort_values(by=["manufacturer"]).reset_index(drop=True)
task14_my = task14_my.sort_values(by=["manufacturer"]).reset_index(drop=True)

# Verify both DataFrames are identical
pd.testing.assert_frame_equal(task14_sql, task14_my)

# %%
print(pd.testing.assert_frame_equal(task14_sql, task14_my))
# Out:
# None

# %% [markdown]
# - Observations:
#
# - - planes.groupby('manufacturer') → Groups the planes DataFrame by the manufacturer column.
# - - .size() → Counts the number of rows in each group, i.e., the number of planes for each manufacturer.
# - - .reset_index(name='howmany') → Resets the index of the grouped DataFrame and renames the resulting column from size to howmany.
# - - .sort_values(by='howmany', ascending=False) → Sorts the DataFrame in descending order based on the howmany column (the count of planes).
# - - .head(10) → Limits the results to the top 10 manufacturers with the most planes.

# %% [markdown]
# **3. 15 SELECT flights.*, planes.year AS plane_year, planes.speed AS plane_speed,
# planes.seats AS plane_seats
# FROM flights LEFT JOIN planes ON flights.tailnum=planes.tailnum**

# %% [markdown]
# - SQL Query Approach

# %%
task15_sql = pd.read_sql_query("""
    SELECT flights.*, planes.year AS plane_year, planes.speed AS plane_speed, planes.seats AS plane_seats
    FROM flights
    LEFT JOIN planes ON flights.tailnum = planes.tailnum
""", conn)

# %%
task15_sql.head()
# Out:
#    year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0  2013      1    1     517.0             515        2.0     830.0
# 1  2013      1    1     533.0             529        4.0     850.0
# 2  2013      1    1     542.0             540        2.0     923.0
# 3  2013      1    1     544.0             545       -1.0    1004.0
# 4  2013      1    1     554.0             600       -6.0     812.0
#
#    sched_arr_time  arr_delay carrier  ...  origin dest air_time distance  \
# 0             819       11.0      UA  ...     EWR  IAH    227.0     1400
# 1             830       20.0      UA  ...     LGA  IAH    227.0     1416
# 2             850       33.0      AA  ...     JFK  MIA    160.0     1089
# 3            1022      -18.0      B6  ...     JFK  BQN    183.0     1576
# 4             837      -25.0      DL  ...     LGA  ATL    116.0      762
#
#    hour  minute      time_hour  plane_year plane_speed  plane_seats
# ...

# %% [markdown]
# - Pandas Equivalent Code (Without SQL)

# %%
task15_my = flights.merge(planes[['tailnum', 'year', 'speed', 'seats']], on='tailnum', how='left')
task15_my = task15_my.rename(columns={'year': 'plane_year', 'speed': 'plane_speed', 'seats': 'plane_seats'})

# %%
task15_my.head()
# Out:
#    year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0  2013      1    1     517.0             515        2.0     830.0
# 1  2013      1    1     533.0             529        4.0     850.0
# 2  2013      1    1     542.0             540        2.0     923.0
# 3  2013      1    1     544.0             545       -1.0    1004.0
# 4  2013      1    1     554.0             600       -6.0     812.0
#
#    sched_arr_time  arr_delay carrier  ...  origin dest air_time distance  \
# 0             819       11.0      UA  ...     EWR  IAH    227.0     1400
# 1             830       20.0      UA  ...     LGA  IAH    227.0     1416
# 2             850       33.0      AA  ...     JFK  MIA    160.0     1089
# 3            1022      -18.0      B6  ...     JFK  BQN    183.0     1576
# 4             837      -25.0      DL  ...     LGA  ATL    116.0      762
#
#    hour  minute      time_hour  plane_year plane_speed  plane_seats
# ...

# %% [markdown]
# - Handling Row Order Differences

# %%
task15_sql = task15_sql.sort_values(by=["tailnum"]).reset_index(drop=True)
task15_my = task15_my.sort_values(by=["tailnum"]).reset_index(drop=True)

# Verify both DataFrames are identical
pd.testing.assert_frame_equal(task15_sql, task15_my)
# Out:
# <ipython-input-114-60a5beb4a5a8>:5: FutureWarning: Mismatched null-like values None and nan found. In a future version, pandas equality-testing functions (e.g. assert_frame_equal) will consider these not-matching and raise.
#   pd.testing.assert_frame_equal(task15_sql, task15_my)

# %%
print(pd.testing.assert_frame_equal(task15_sql, task15_my))
# Out:
# <ipython-input-115-9923317fbe73>:1: FutureWarning: Mismatched null-like values None and nan found. In a future version, pandas equality-testing functions (e.g. assert_frame_equal) will consider these not-matching and raise.
#   print(pd.testing.assert_frame_equal(task15_sql, task15_my))
# None

# %% [markdown]
# - Observations:
#
# - - flights.merge(planes[['tailnum', 'year', 'speed', 'seats']], on='tailnum', how='left'):
#
# - - - This performs a merge (similar to a SQL JOIN) between the flights DataFrame and a subset of the planes DataFrame (which includes only the tailnum, year, speed, and seats columns).
# - - - The on='tailnum' argument specifies the common column between the two DataFrames, and how='left' specifies that we want to keep all rows from the flights DataFrame and match them with rows from the planes DataFrame where possible. If there is no match, the columns from planes will be filled with NaN.
# - - .rename(columns={'year': 'plane_year', 'speed': 'plane_speed', 'seats': 'plane_seats'}):
#
# - - - This renames the columns year, speed, and seats to plane_year, plane_speed, and plane_seats, just as the SQL query does.

# %% [markdown]
# **3. 16 SELECT planes.*, airlines.* FROM
# (SELECT DISTINCT carrier, tailnum FROM flights) AS cartail
# INNER JOIN planes ON cartail.tailnum=planes.tailnum
# INNER JOIN airlines ON cartail.carrier=airlines.carrier**

# %% [markdown]
# - SQL Query Approach

# %%
task16_sql = pd.read_sql_query("""
    SELECT planes.*, airlines.*
    FROM (SELECT DISTINCT carrier, tailnum FROM flights) AS cartail
    INNER JOIN planes ON cartail.tailnum = planes.tailnum
    INNER JOIN airlines ON cartail.carrier = airlines.carrier
""", conn)

# %%
task16_sql.head()
# Out:
#   tailnum    year                     type      manufacturer      model  \
# 0  N10156  2004.0  Fixed wing multi engine           EMBRAER  EMB-145XR
# 1  N102UW  1998.0  Fixed wing multi engine  AIRBUS INDUSTRIE   A320-214
# 2  N103US  1999.0  Fixed wing multi engine  AIRBUS INDUSTRIE   A320-214
# 3  N104UW  1999.0  Fixed wing multi engine  AIRBUS INDUSTRIE   A320-214
# 4  N10575  2002.0  Fixed wing multi engine           EMBRAER  EMB-145LR
#
#    engines  seats  speed     engine carrier                      name
# 0        2     55    NaN  Turbo-fan      EV  ExpressJet Airlines Inc.
# 1        2    182    NaN  Turbo-fan      US           US Airways Inc.
# 2        2    182    NaN  Turbo-fan      US           US Airways Inc.
# 3        2    182    NaN  Turbo-fan      US           US Airways Inc.
# 4        2     55    NaN  Turbo-fan      EV  ExpressJet Airlines Inc.

# %% [markdown]
# - Pandas Equivalent Code (Without SQL)

# %%
cartail = flights[['carrier', 'tailnum']].drop_duplicates()
task16_my = cartail.merge(planes, on='tailnum', how='inner') \
                   .merge(airlines, on='carrier', how='inner')

# %%
task16_my.head()
# Out:
#   tailnum    year                     type      manufacturer      model  \
# 0  N10156  2004.0  Fixed wing multi engine           EMBRAER  EMB-145XR
# 1  N102UW  1998.0  Fixed wing multi engine  AIRBUS INDUSTRIE   A320-214
# 2  N103US  1999.0  Fixed wing multi engine  AIRBUS INDUSTRIE   A320-214
# 3  N104UW  1999.0  Fixed wing multi engine  AIRBUS INDUSTRIE   A320-214
# 4  N10575  2002.0  Fixed wing multi engine           EMBRAER  EMB-145LR
#
#    engines  seats  speed     engine carrier                      name
# 0        2     55    NaN  Turbo-fan      EV  ExpressJet Airlines Inc.
# 1        2    182    NaN  Turbo-fan      US           US Airways Inc.
# 2        2    182    NaN  Turbo-fan      US           US Airways Inc.
# 3        2    182    NaN  Turbo-fan      US           US Airways Inc.
# 4        2     55    NaN  Turbo-fan      EV  ExpressJet Airlines Inc.

# %% [markdown]
# - Handling Row Order Differences

# %%
task16_sql = task16_sql.sort_values(by=["tailnum", "carrier"]).reset_index(drop=True)
task16_my = task16_my.sort_values(by=["tailnum", "carrier"]).reset_index(drop=True)

# Verify both DataFrames are identical
pd.testing.assert_frame_equal(task16_sql, task16_my)

# %%
print(pd.testing.assert_frame_equal(task16_sql, task16_my) )
# Out:
# None

# %% [markdown]
# - Observations:
#
# - - flights[['carrier', 'tailnum']].drop_duplicates():
#
# - - - Selects the carrier and tailnum columns from the flights DataFrame.
# - - - drop_duplicates() ensures that only unique pairs of carrier and tailnum are selected, which is equivalent to the subquery in SQL that uses DISTINCT.
# - - .merge(planes, on='tailnum', how='inner'):
#
# - - - This performs an inner join between cartail (which contains distinct carrier and tailnum pairs) and the planes DataFrame, matching on the tailnum column.
# - - .merge(airlines, on='carrier', how='inner'):
#
# - - - After the first merge, this performs another inner join between the resulting DataFrame and the airlines DataFrame, matching on the carrier column.

# %% [markdown]
# **3. 17 SELECT flights2.*, atemp, ahumid
# FROM (
# SELECT * FROM flights WHERE origin='EWR'
# ) AS flights2 LEFT JOIN (
# SELECT year, month, day, AVG(temp) AS atemp,
# AVG(humid) AS ahumid
# FROM weather
# WHERE origin='EWR'
# GROUP BY year, month, day ) AS weather2
# ON flights2.year=weather2.year
# AND flights2.month=weather2.month
# AND flights2.day=weather2.day**

# %% [markdown]
# - SQL Query Approach

# %%
task17_sql = pd.read_sql_query("""
    SELECT flights2.*, atemp, ahumid
    FROM (
        SELECT * FROM flights WHERE origin='EWR'
    ) AS flights2
    LEFT JOIN (
        SELECT year, month, day, AVG(temp) AS atemp, AVG(humid) AS ahumid
        FROM weather
        WHERE origin='EWR'
        GROUP BY year, month, day
    ) AS weather2
    ON flights2.year = weather2.year
    AND flights2.month = weather2.month
    AND flights2.day = weather2.day
""", conn)

# %%
task17_sql.head()
# Out:
#    year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0  2013      1    1     517.0             515        2.0     830.0
# 1  2013      1    1     554.0             558       -4.0     740.0
# 2  2013      1    1     555.0             600       -5.0     913.0
# 3  2013      1    1     558.0             600       -2.0     923.0
# 4  2013      1    1     559.0             600       -1.0     854.0
#
#    sched_arr_time  arr_delay carrier  ...  tailnum origin dest air_time  \
# 0             819       11.0      UA  ...   N14228    EWR  IAH    227.0
# 1             728       12.0      UA  ...   N39463    EWR  ORD    150.0
# 2             854       19.0      B6  ...   N516JB    EWR  FLL    158.0
# 3             937      -14.0      UA  ...   N53441    EWR  SFO    361.0
# 4             902       -8.0      UA  ...   N76515    EWR  LAS    337.0
#
#    distance  hour  minute      time_hour  atemp     ahumid
# 0      1400     5      15  1/1/2013 5:00  38.48  58.386087
# ...

# %% [markdown]
# - Pandas Equivalent Code (Without SQL)

# %%
# Filter flights data for origin='EWR'
flights2 = flights[flights['origin'] == 'EWR']

# Calculate the average temp and humidity from weather data, grouped by year, month, day
weather2 = weather[weather['origin'] == 'EWR']
weather2 = weather2.groupby(['year', 'month', 'day'], as_index=False).agg(atemp=('temp', 'mean'), ahumid=('humid', 'mean'))

# Merge the flights data with the weather data on year, month, and day
task17_my = pd.merge(flights2, weather2, on=['year', 'month', 'day'], how='left')

# %%
task17_my.head()
# Out:
#    year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0  2013      1    1     517.0             515        2.0     830.0
# 1  2013      1    1     554.0             558       -4.0     740.0
# 2  2013      1    1     555.0             600       -5.0     913.0
# 3  2013      1    1     558.0             600       -2.0     923.0
# 4  2013      1    1     559.0             600       -1.0     854.0
#
#    sched_arr_time  arr_delay carrier  ...  tailnum origin dest air_time  \
# 0             819       11.0      UA  ...   N14228    EWR  IAH    227.0
# 1             728       12.0      UA  ...   N39463    EWR  ORD    150.0
# 2             854       19.0      B6  ...   N516JB    EWR  FLL    158.0
# 3             937      -14.0      UA  ...   N53441    EWR  SFO    361.0
# 4             902       -8.0      UA  ...   N76515    EWR  LAS    337.0
#
#    distance  hour  minute      time_hour  atemp     ahumid
# 0      1400     5      15  1/1/2013 5:00  38.48  58.386087
# ...

# %% [markdown]
# - Handling Row Order Differences

# %%
task17_sql = task17_sql.sort_values(by=["year", "month", "day"]).reset_index(drop=True)
task17_my = task17_my.sort_values(by=["year", "month", "day"]).reset_index(drop=True)

# Verify both DataFrames are identical
pd.testing.assert_frame_equal(task17_sql, task17_my)
# Out:
# <ipython-input-125-e01dda1c4404>:5: FutureWarning: Mismatched null-like values None and nan found. In a future version, pandas equality-testing functions (e.g. assert_frame_equal) will consider these not-matching and raise.
#   pd.testing.assert_frame_equal(task17_sql, task17_my)

# %%
print(pd.testing.assert_frame_equal(task17_sql, task17_my))
# Out:
# <ipython-input-126-9eadcb61f512>:1: FutureWarning: Mismatched null-like values None and nan found. In a future version, pandas equality-testing functions (e.g. assert_frame_equal) will consider these not-matching and raise.
#   print(pd.testing.assert_frame_equal(task17_sql, task17_my))
# None

# %% [markdown]
# - Observations:
#
# - - flights2 = flights[flights['origin'] == 'EWR']:
#
# - - - Filters the flights DataFrame to include only rows where the origin is 'EWR'.
# - - weather2 = weather[weather['origin'] == 'EWR']:
#
# - - - Filters the weather DataFrame to include only rows where the origin is 'EWR'.
# - - weather2.groupby(['year', 'month', 'day'], as_index=False).agg(...):
#
# - - - Groups the weather DataFrame by year, month, and day and calculates the average temperature (atemp) and average humidity (ahumid) for each group. This is equivalent to the SQL AVG() function.
# - - pd.merge(flights2, weather2, on=['year', 'month', 'day'], how='left'):
#
# - - - Merges the two DataFrames (flights2 and weather2) on the year, month, and day columns using a left join (keeping all rows from flights2 and adding matching data from weather2).

# %%
# Let'us close the connection
conn.close()

# %% [markdown]
# # Conclusion

# %% [markdown]
# Both SQL and Pandas are effective for data wrangling, with SQL being ideal for large datasets and Pandas excelling in smaller datasets and complex analysis within Python.

# %% [markdown]
# # Recommendations

# %% [markdown]
# Use Pandas for smaller, in-memory data tasks and SQL for large-scale data management; integrate both for optimal performance—SQL for retrieval and Pandas for analysis.

# %% [markdown]
# # Way Forward

# %% [markdown]
# Focus on improving skills in both SQL and Pandas, optimize data workflows, and explore advanced tools like SQLAlchemy and Dask for enhanced performance and scalability in data processing.
